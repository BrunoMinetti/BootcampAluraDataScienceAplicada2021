# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoMinetti/BootcampAluraDataScienceAplicada2021/blob/main/BootcampAluraDataScienceAplicada2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aluno: Bruno Sanches
# Esse notebook acompanha as videoaula do Bootcamp da Alura: Data Science Aplicada 2021.<p>
# Caderno de exploração dos dados do datasus 2008 para frente.

# %% [markdown]
# # Módulo 01: Python e pandas para análise de dados reais
# ### Curso "Analisando dados da saúde com Python e Pandas"

# %% [markdown]
# ## Aula1
# ## Aquisição e leitura de dados reais:
# - Introdução
# - Preparando o ambiente
# - Produção hospitalar e Pandas
# - Visualizações e gráficos
# - Desafio
# - O que aprendemos?

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/BrunoMinetti/BootcampAluraDataScienceAplicada2021/main/A160324189_28_143_208.csv", encoding = "ISO-8859-1", skiprows = 3, sep=";", skipfooter=12, thousands=".", decimal=",")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados['2008/Ago']
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(12,8))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(12,8))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))

plt.title("Valor recebido por cada unidade da federação no mês de agosto de 2008")
plt.show()

# %% [markdown]
# ### Desafio: escolher um título mais descritivo que passe a mensagem adequada.

# %% [markdown]
# ## Aula 2
# ## Primeiras visualizações de dados:
# - Entendendo gráficos
# - Desafio
# - O que aprendemos?

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
usaveis = usaveis.set_index('Unidade da Federação')
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  929129659.72
# 12 Acre               10470.07  14001.71  ...  1163813.08  420668039.63
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1771654871.23
# 14 Roraima             4785.91  11858.63  ...  2739498.41  305010883.18
# 15 Pará              181159.29 433414.74  ... 27618727.51 4437115730.71
#
# [5 rows x 157 columns]

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Abr               7423678.64  ...          18123899.78
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %%
usaveis.plot(figsize=(12,6))

# %%
usaveis.T.plot(figsize=(12,6))

# %%
usaveis = usaveis.drop("Total", axis=1)

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# 2020/Jul               7407388.24 1163813.08  ... 33499284.38          22233542.26
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# ###Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %% [markdown]
# ## Aula 3
# ## Manipulação de dados:
# - Aleatoriedade e mais explorações
# - Ordenação e série temporal
# - Desafio
# - O que aprendemos?

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[0:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jun    2020/Jul
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  9193593.76  7407388.24
# 12 Acre               10470.07  14001.71  ...  2199920.70  1163813.08
# 13 Amazonas           35752.72  45570.64  ... 17509334.66 13358514.02
# 14 Roraima             4785.91  11858.63  ...  3216466.51  2739498.41
# 15 Pará              181159.29 433414.74  ... 35396030.78 27618727.51
#
# [5 rows x 156 columns]

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis[:7].T.plot(figsize=(10,6))

# %%
usaveis.sample(n=7).T.plot(figsize=(10,6))

# %%
import numpy as np

np.random.seed(687942)
usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  27450865.16  27460475.47
# 31 Minas Gerais        971394.37 2861781.50  ... 135977571.87 120467187.34
# 24 Rio Grande do Norte 134605.36  272088.08  ...  20219961.81  19593057.45
# 17 Tocantins             4113.76   76633.06  ...   5018138.13   4489665.87
# 53 Distrito Federal    191951.47  769966.25  ...  23479773.03  22233542.26
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  15838659.34  12508717.35
# 16 Amapá                33672.74  104822.98  ...   2699492.23   2155083.37
#
# [7 rows x 156 columns]

# %%
usaveis.sample(n=7)
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 42 Santa Catarina     693955.05 1092964.12  ...  56503747.99  51764534.76
# 33 Rio de Janeiro     469469.34  921646.57  ...  77604925.21  71540227.33
# 31 Minas Gerais       971394.37 2861781.50  ... 135977571.87 120467187.34
# 35 São Paulo         1665349.90 4434168.64  ... 299060851.62 282709570.31
# 21 Maranhão           385330.18 1018352.93  ...  31128144.66  24374205.15
# 52 Goiás              179395.82  418053.58  ...  34437633.20  33499284.38
# 32 Espírito Santo      57408.11  284224.80  ...  27450865.16  27460475.47
#
# [7 rows x 156 columns]

# %% [markdown]
# ### Desafio: criar uma coluna mostrando a região de cada um dos estados

# %%
usaveis.sum()
# Out:
# 2007/Ago      8233724.90
# 2007/Set     21279921.98
# 2007/Out     65884400.02
# 2007/Nov    148968559.33
# 2007/Dez    333103304.40
#                 ...
# 2020/Mar   1221372739.53
# 2020/Abr   1080153330.85
# 2020/Mai   1262763751.01
# 2020/Jun   1224918442.85
# 2020/Jul   1099361266.73
# Length: 156, dtype: float64

# %%
usaveis["Total"] = usaveis.sum(axis=1)

# %%
usaveis["Total"]
# Out:
# Unidade da Federação
# 11 Rondônia                925572673.82
# 12 Acre                    420666755.81
# 13 Amazonas               1766925554.09
# 14 Roraima                 303485991.45
# 15 Pará                   4425537480.57
# 16 Amapá                   290781699.72
# 17 Tocantins               997507241.35
# 21 Maranhão               3621885105.60
# 22 Piauí                  2122676207.29
# 23 Ceará                  6182786402.04
# 24 Rio Grande do Norte    2469235766.39
# 25 Paraíba                2461941658.63
# 26 Pernambuco             8013135105.77
# 27 Alagoas                2097903424.04
# 28 Sergipe                1128585323.09
# 29 Bahia                  9167733691.21
# 31 Minas Gerais          19102100731.94
# 32 Espírito Santo         3128353199.69
# 33 Rio de Janeiro         9659938007.12
# 35 São Paulo             38779063638.12
# 41 Paraná                13745248985.60
# 42 Santa Catarina         7306969709.51
# 43 Rio Grande do Sul     11930181093.98
# ...

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2020/Jul         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  7407388.24  925572673.82
# 12 Acre               10470.07  14001.71  ...  1163813.08  420666755.81
# 13 Amazonas           35752.72  45570.64  ... 13358514.02 1766925554.09
# 14 Roraima             4785.91  11858.63  ...  2739498.41  303485991.45
# 15 Pará              181159.29 433414.74  ... 27618727.51 4425537480.57
#
# [5 rows x 157 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
ordenado_por_total.index = ordenado_por_total.index.str[3:]
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)

# %%
ordenado_por_total.head(5).T.plot(figsize=(15,6))

# %% [markdown]
# ### Desafio: adicione seu estado aos 5 estados existentes e plote

# %%
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# São Paulo            1665349.90 4434168.64  ... 299060851.62 282709570.31
# Minas Gerais          971394.37 2861781.50  ... 135977571.87 120467187.34
# Paraná                554800.22 1431708.01  ...  92901461.36  80320852.69
# Rio Grande do Sul    1049252.33 3182913.14  ...  89019478.82  78929703.81
# Rio de Janeiro        469469.34  921646.57  ...  77604925.21  71540227.33
#
# [5 rows x 156 columns]

# %%
ordenado_por_total.T["Minas Gerais"].max()
# Out:
# 205912743.65

# %%
ordenado_por_total = ordenado_por_total.drop("2008/Jan", axis=1)

# %%
ordenado_por_total.head(5).T.plot(figsize=(15,6))

# %%
colunas_interessantes = ordenado_por_total.columns[5:]
ordenado_por_total[colunas_interessantes].head()
# Out:
#                          2008/Fev     2008/Mar  ...     2020/Jun     2020/Jul
# Unidade da Federação                            ...
# São Paulo            172834914.73 170481849.56  ... 299060851.62 282709570.31
# Minas Gerais          70301089.50  79119005.51  ... 135977571.87 120467187.34
# Paraná                48855046.46  55611791.07  ...  92901461.36  80320852.69
# Rio Grande do Sul     45897704.82  52928695.92  ...  89019478.82  78929703.81
# Rio de Janeiro        44122593.19  42892665.52  ...  77604925.21  71540227.33
#
# [5 rows x 150 columns]

# %%
ordenado_por_total = ordenado_por_total[colunas_interessantes]

# %%
ordenado_por_total.head(5).T.plot(figsize=(15,6))

# %% [markdown]
# Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.
#
# Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.
#
# Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável (Bonitão, segundo o Gui)
#
# Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente
#
# Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue
#
# Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região
#
# Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo e tire conclusões sobre seus estados comparando com os demais. Tire suas conclusões e compartilhe com a gente.

# %% [markdown]
# https://github.com/alura-cursos/agendamento-hospitalar/blob/main/notebooks%20por%20aula/aula41/Bootcamp%20Data%20Science%20Alura%20-%20Agendamento%20Hospitalar.ipynb

# %%
'''
ideia de como funciona aleatoriedade
pseudo randomness

seed = 6987
random = seed / 10, seed = seed * 2 /3


random ===> 698...... (seed=4658)
random ==> 465 (seed = 310)
random ==> 31
'''
# Out:
# '\nideia de como funciona aleatoriedade\npseudo randomness\n\nseed = 6987\nrandom = seed / 10, seed = seed * 2 /3\n\n\nrandom ===> 698...... (seed=4658)\nrandom ==> 465 (seed = 310)\nrandom ==> 31\n'

# %% [markdown]
# ## Aula 4
# ## Análise de gráficos e criação de hipótese:
# - Fugindo de más práticas
# - Desafio
# - O que aprendemos?

# %%
ordenado_por_total /= 1000000
ordenado_por_total.head(5).T.plot(figsize=(15,6))

# %%
meses_filtrados = ordenado_por_total.columns[48:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (10,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize = (10,6))
plt.ylim(100,350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(5).T.plot(figsize = (6,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(5).T.plot(figsize = (10,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Desafio 01: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações
#
# Desafio 02: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord.
#
#
# https://github.com/alura-cursos/agendamento-hospitalar/blob/main/notebooks%20por%20aula/aula41/Bootcamp%20Data%20Science%20Alura%20-%20Agendamento%20Hospitalar.ipynb

# %% [markdown]
# ## Aula 5
# ## Manipulação e interpretação de gráficos:
# - Alternativas de visualizações
# - Desafio
# - Conclusão
# - O que aprendemos?

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mes_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mes_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           282.71
# Minas Gerais        120.47
# Paraná               80.32
# Rio Grande do Sul    78.93
# Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mes_mais_recente.plot()

# %%
gastos_do_mes_mais_recente.plot(kind = "pie")

# %% [markdown]
# Horrores da pizza (pie):
# - Legenda está horrivel
# - Número de fátias inacreditável
#
# Já estamos com uma vantagem:
# - Os dados do gráfico estarem ordenados.

# %%
gastos_do_mes_mais_recente.sample(frac=1).plot(kind = 'pie')

# %% [markdown]
# Horrores da pizza (pie):
# - Legenda está horrivel
# - Número de fátias inacreditável
# - Não dá para saber a ordem.
# - Cores repetidas
# - Não sei a proporção
# - Muito ruim para saber a ordem
# - Muito ruim para comparar

# %%
# visualização simples para valor absoluto

gastos_do_mes_mais_recente = gastos_do_mes_mais_recente.sort_values(ascending=False)
gastos_do_mes_mais_recente
# Out:
# Unidade da Federação
# São Paulo             282.71
# Minas Gerais          120.47
# Paraná                 80.32
# Rio Grande do Sul      78.93
# Rio de Janeiro         71.54
# Pernambuco             62.33
# Bahia                  58.90
# Santa Catarina         51.76
# Goiás                  33.50
# Ceará                  30.81
# Pará                   27.62
# Espírito Santo         27.46
# Maranhão               24.37
# Distrito Federal       22.23
# Rio Grande do Norte    19.59
# Piauí                  18.02
# Paraíba                15.49
# Amazonas               13.36
# Alagoas                13.09
# Mato Grosso            13.08
# Mato Grosso do Sul     12.51
# Rondônia                7.41
# Tocantins               4.49
# Sergipe                 3.31
# Roraima                 2.74
# Amapá                   2.16
# Acre                    1.16
# Name: 2020/Jul, dtype: float64

# %%
rio_compara_frac = (gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['Rio de Janeiro'])
rio_compara_frac
# Out:
# Unidade da Federação
# São Paulo             3.95
# Minas Gerais          1.68
# Paraná                1.12
# Rio Grande do Sul     1.10
# Rio de Janeiro        1.00
# Pernambuco            0.87
# Bahia                 0.82
# Santa Catarina        0.72
# Goiás                 0.47
# Ceará                 0.43
# Pará                  0.39
# Espírito Santo        0.38
# Maranhão              0.34
# Distrito Federal      0.31
# Rio Grande do Norte   0.27
# Piauí                 0.25
# Paraíba               0.22
# Amazonas              0.19
# Alagoas               0.18
# Mato Grosso           0.18
# Mato Grosso do Sul    0.17
# Rondônia              0.10
# Tocantins             0.06
# Sergipe               0.05
# Roraima               0.04
# Amapá                 0.03
# Acre                  0.02
# Name: 2020/Jul, dtype: float64

# %% [markdown]
# Criar a tabela de comparação com o seu estado(ou estado de preferência)

# %%
rio_compara_frac.plot(kind='bar', figsize = (15,6))
plt.ylim(4,0)
# Out:
# (4.0, 0.0)

# %%
rio_compara_frac.head(5).plot(kind='bar', figsize = (12,6))

# %% [markdown]
# Desafio: procurar na documentação do matplotlib e pandas para colocar grid no gráfico

# %%
rio_compara_frac.head()
# Out:
# Unidade da Federação
# São Paulo           3.95
# Minas Gerais        1.68
# Paraná              1.12
# Rio Grande do Sul   1.10
# Rio de Janeiro      1.00
# Name: 2020/Jul, dtype: float64

# %%
sp_compara_frac = (gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['São Paulo'])
sp_compara_frac
# Out:
# Unidade da Federação
# São Paulo             1.00
# Minas Gerais          0.43
# Paraná                0.28
# Rio Grande do Sul     0.28
# Rio de Janeiro        0.25
# Pernambuco            0.22
# Bahia                 0.21
# Santa Catarina        0.18
# Goiás                 0.12
# Ceará                 0.11
# Pará                  0.10
# Espírito Santo        0.10
# Maranhão              0.09
# Distrito Federal      0.08
# Rio Grande do Norte   0.07
# Piauí                 0.06
# Paraíba               0.05
# Amazonas              0.05
# Alagoas               0.05
# Mato Grosso           0.05
# Mato Grosso do Sul    0.04
# Rondônia              0.03
# Tocantins             0.02
# Sergipe               0.01
# Roraima               0.01
# Amapá                 0.01
# Acre                  0.00
# Name: 2020/Jul, dtype: float64

# %%
sp_compara_frac.plot(kind='bar', figsize=(15,6))
plt.ylim(1,0)
# Out:
# (1.0, 0.0)

# %% [markdown]
# https://github.com/alura-cursos/agendamento-hospitalar/blob/main/notebooks%20por%20aula/aula51/Bootcamp%20Data%20Science%20Alura%20-%20Agendamento%20Hospitalar.ipynb
#
# ## Super desafio = > Escolher outro valor fora o Valor Aprovado no TABNET e explorar
#
# https://colab.research.google.com/drive/1wySU77EoGdpeNmJikKlR6i6T339IU2_0

# %% [markdown]
# # Módulo 02: Visualização de dados com Seaborn e Matplotlib
# ### Curso "Tratamento, exploração e visualização de dados"

# %% [markdown]
# ## Aula 01 Usando fontes alternativas de dados

# %%
sp_compara_frac.plot(kind='bar', figsize=(15,6))

# %%
gastos_do_mes_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           282.71
# Minas Gerais        120.47
# Paraná               80.32
# Rio Grande do Sul    78.93
# Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_proporcionais = gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.sum()
gastos_proporcionais.plot(kind='bar')

# %%
#ler Excel
ibge_estimativa = pd.read_excel('https://github.com/BrunoMinetti/BootcampAluraDataScienceAplicada2021/blob/main/POP2020_20201030.xls?raw=true')
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  ...          Unnamed: 2
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO                                                                  ...  POPULAÇÃO ESTIMADA
# 1                                             Brasil                                                                  ...           211755692
# 2                                       Região Norte                                                                  ...            18672591
# 3                                           Rondônia                                                                  ...             1796460
# 4                                               Acre                                                                  ...              894470
#
# [5 rows x 3 columns]

# %%
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 331 292	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 279 638	3,4%	 Sérvia (7 114 393)
12	 Goiás	7 142 070	3,4%	 Paraguai (7 003 406)
11	 Maranhão	7 127 460	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 228 381	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""
# fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
from io import StringIO
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep='\t').dropna()
populacao['populacao'] = populacao['População'].str.\
replace(' ','').astype(int)
populacao['uf'] = populacao['Unidade federativa']
display(populacao.head())
display(populacao.info())
# Out:
#   Posição Unidade federativa  ... populacao               uf
# 1       1          São Paulo  ...  46289333        São Paulo
# 2       2       Minas Gerais  ...  21331292     Minas Gerais
# 3       3     Rio de Janeiro  ...  17366189   Rio de Janeiro
# 4       4        Bahia Bahia  ...  14930634      Bahia Bahia
# 5       5             Paraná  ...  11516840           Paraná
#
# [5 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 1 to 27
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Posição             27 non-null     object
#  1   Unidade federativa  27 non-null     object
#  2   População           27 non-null     object
#  3   % da pop. total     27 non-null     object
#  4   País comparável     27 non-null     object
#  5   populacao           27 non-null     int64
#  6   uf                  27 non-null     object
# dtypes: int64(1), object(6)
# ...

# %% [markdown]
# ###Desafio: ler esse arquivo direto da página de internet, Wikipedia(html)

# %%
wiki = 'https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o'

wiki_direct = pd.read_html(wiki)

wiki_direct
# Out:
# [    Posição  ...        País comparável (habitantes)
#  0         1  ...                Espanha (46 439 864)
#  1         2  ...              Sri Lanka (20 675 000)
#  2         3  ...          Países Baixos (16 922 900)
#  3         4  ...                  Chade (14 037 000)
#  4         5  ...                Bolívia (11 410 651)
#  5         6  ...                Bélgica (11 250 659)
#  6         7  ...            Bielorrússia (9 485 300)
#  7         8  ...  Emirados Árabes Unidos (9 157 000)
#  8         9  ...                 Áustria (8 602 112)
#  9        10  ...                  Sérvia (7 114 393)
#  10       11  ...                Paraguai (7 003 406)
#  11       12  ...                Paraguai (7 003 406)
#  12       13  ...                  Líbano (4 168 000)
#  13       14  ...                  Líbano (4 168 000)
#  14       15  ...                  Líbano (4 168 000)
#  15       16  ...                 Uruguai (3 415 866)
# ...

# %%
populacao_direct = wiki_direct[0]
populacao_direct.head()
# Out:
#    Posição Unidade federativa  ... % da pop. total País comparável (habitantes)
# 0        1          São Paulo  ...           21,9%         Espanha (46 439 864)
# 1        2       Minas Gerais  ...           10,1%       Sri Lanka (20 675 000)
# 2        3     Rio de Janeiro  ...            8,2%   Países Baixos (16 922 900)
# 3        4              Bahia  ...            7,1%           Chade (14 037 000)
# 4        5             Paraná  ...            5,4%         Bolívia (11 410 651)
#
# [5 rows x 5 columns]

# %%
# daqui para frente as tratativas seriam iguais.

# %% [markdown]
# ## Aula 02 Manipulação e junção de tabelas

# %%
'Bruno'[:3]
# Out:
# 'Bru'

# %%
populacao['uf'][:3]
# Out:
# 1          São Paulo
# 2       Minas Gerais
# 3     Rio de Janeiro
# Name: uf, dtype: object

# %%
#para pegar os 3 primeiros caracteres de cada estado
populacao['uf'].str[:3]
# Out:
# 1      Sã
# 2      Mi
# 3      Ri
# 4     Bah
# 5      Pa
# 6      Ri
# 7      Pe
# 8      Ce
# 9     Par
# 10     Sa
# 11     Go
# 12     Ma
# 13     Am
# 14     Es
# 15     Pa
# 16     Ri
# 17     Ma
# 18     Al
# 19     Pi
# 20     Di
# 21     Ma
# 22     Se
# 23     Ro
# 24     To
# 25     Ac
# 26     Am
# 27     Ro
# Name: uf, dtype: object

# %%
populacao = populacao[['uf', 'populacao']]
populacao
# Out:
#                       uf  populacao
# 1              São Paulo   46289333
# 2           Minas Gerais   21331292
# 3         Rio de Janeiro   17366189
# 4            Bahia Bahia   14930634
# 5                 Paraná   11516840
# 6      Rio Grande do Sul   11422973
# 7             Pernambuco    9616621
# 8                  Ceará    9187103
# 9              Pará Pará    8690745
# 10        Santa Catarina    7279638
# 11                 Goiás    7142070
# 12              Maranhão    7127460
# 13              Amazonas    4228381
# 14        Espírito Santo    4064052
# 15               Paraíba    4039277
# 16   Rio Grande do Norte    3534165
# 17           Mato Grosso    3526220
# 18               Alagoas    3351543
# 19                 Piauí    3281480
# 20      Distrito Federal    3055149
# 21    Mato Grosso do Sul    2809394
# 22               Sergipe    2318822
# 23              Rondônia    1796460
# 24             Tocantins    1590248
# 25                  Acre     894470
# ...

# %%
populacao = populacao.set_index('uf')

# %%
populacao.index
# Out:
# Index([' São Paulo', ' Minas Gerais', ' Rio de Janeiro', 'Bahia Bahia',
#        ' Paraná', ' Rio Grande do Sul', ' Pernambuco', ' Ceará', 'Pará Pará',
#        ' Santa Catarina', ' Goiás', ' Maranhão', ' Amazonas',
#        ' Espírito Santo', ' Paraíba', ' Rio Grande do Norte', ' Mato Grosso',
#        ' Alagoas', ' Piauí', ' Distrito Federal', ' Mato Grosso do Sul',
#        ' Sergipe', ' Rondônia', ' Tocantins', ' Acre', ' Amapá', ' Roraima'],
#       dtype='object', name='uf')

# %%
populacao.index.str[:3]
# Out:
# Index([' Sã', ' Mi', ' Ri', 'Bah', ' Pa', ' Ri', ' Pe', ' Ce', 'Par', ' Sa',
#        ' Go', ' Ma', ' Am', ' Es', ' Pa', ' Ri', ' Ma', ' Al', ' Pi', ' Di',
#        ' Ma', ' Se', ' Ro', ' To', ' Ac', ' Am', ' Ro'],
#       dtype='object', name='uf')

# %%
populacao.join(gastos_do_mes_mais_recente)
# Out:
#                       populacao  2020/Jul
# uf
#  São Paulo             46289333       nan
#  Minas Gerais          21331292       nan
#  Rio de Janeiro        17366189       nan
# Bahia Bahia            14930634       nan
#  Paraná                11516840       nan
#  Rio Grande do Sul     11422973       nan
#  Pernambuco             9616621       nan
#  Ceará                  9187103       nan
# Pará Pará               8690745       nan
#  Santa Catarina         7279638       nan
#  Goiás                  7142070       nan
#  Maranhão               7127460       nan
#  Amazonas               4228381       nan
#  Espírito Santo         4064052       nan
#  Paraíba                4039277       nan
#  Rio Grande do Norte    3534165       nan
#  Mato Grosso            3526220       nan
#  Alagoas                3351543       nan
#  Piauí                  3281480       nan
#  Distrito Federal       3055149       nan
#  Mato Grosso do Sul     2809394       nan
# ...

# %% [markdown]
# ###Desafio: Para nós, aqui em cima, na importação dos dados da Wikipédia, estruturarmos uma função e invocá-la, claro, para a leitura e limpeza dessa tabela, devolvendo a tabela populacao e a tabela unida com gastos_do_mais_recente, que são os gastos_e_populacao_recente.

# %%
def limp_dados_join(populacao, gastos_do_mes_mais_recente):
    #o índice tinha um espaço a mais no começo ou no fim e não estava permitindo o join
    populacao.index = populacao.index.str.strip()
    # Removendo os estados que sairam duplicados por conta do "alt" da imagem no HTML da página.
    for estado in gastos_do_mes_mais_recente.index:
        populacao.index = populacao.index.str.replace(f'{estado} {estado}', estado)
    #Join com as duas colunas
    return populacao.join(gastos_do_mes_mais_recente)

# %%
gastos_e_populacao = limp_dados_join(populacao, gastos_do_mes_mais_recente)
gastos_e_populacao
# Out:
#                      populacao  2020/Jul
# uf
# São Paulo             46289333    282.71
# Minas Gerais          21331292    120.47
# Rio de Janeiro        17366189     71.54
# Bahia                 14930634     58.90
# Paraná                11516840     80.32
# Rio Grande do Sul     11422973     78.93
# Pernambuco             9616621     62.33
# Ceará                  9187103     30.81
# Pará                   8690745     27.62
# Santa Catarina         7279638     51.76
# Goiás                  7142070     33.50
# Maranhão               7127460     24.37
# Amazonas               4228381     13.36
# Espírito Santo         4064052     27.46
# Paraíba                4039277     15.49
# Rio Grande do Norte    3534165     19.59
# Mato Grosso            3526220     13.08
# Alagoas                3351543     13.09
# Piauí                  3281480     18.02
# Distrito Federal       3055149     22.23
# Mato Grosso do Sul     2809394     12.51
# Sergipe                2318822      3.31
# ...

# %% [markdown]
# ## Aula 03 - Visualização, Seaborn e Proporcionalidades

# %%
def insere_gastos_e_gasto_por_habitante_para(todos_os_gastos, dados, mes: str):
    gastos_do_mes = todos_os_gastos[mes]
    dados[f'gastos_{mes}'] = gastos_do_mes * 1000000
    dados[f'gasto_por_habitante_{mes}'] = dados[f'gastos_{mes}'] / dados['populacao']

# %%
#Muito ruim, horripilante (data visualization)
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total,gastos_e_populacao,'2020/Jul')
gastos_e_populacao[['gastos_2020/Jul','populacao']].plot()

# %%
ordenado_por_total
# Out:
#                       2008/Fev  2008/Mar  ...  2020/Jun  2020/Jul
# Unidade da Federação                      ...
# São Paulo               172.83    170.48  ...    299.06    282.71
# Minas Gerais             70.30     79.12  ...    135.98    120.47
# Paraná                   48.86     55.61  ...     92.90     80.32
# Rio Grande do Sul        45.90     52.93  ...     89.02     78.93
# Rio de Janeiro           44.12     42.89  ...     77.60     71.54
# Bahia                    33.41     41.30  ...     65.16     58.90
# Pernambuco               26.22     30.72  ...     68.15     62.33
# Santa Catarina           24.41     27.48  ...     56.50     51.76
# Ceará                    27.64     30.09  ...     42.15     30.81
# Goiás                    18.15     20.99  ...     34.44     33.50
# Pará                     20.13     22.15  ...     35.40     27.62
# Maranhão                 13.45     14.75  ...     31.13     24.37
# Espírito Santo           10.03     12.26  ...     27.45     27.46
# ...

# %%
gastos_e_populacao.loc[['Rio Grande do Sul','São Paulo']]
# Out:
#                    populacao  ...  gasto_por_habitante_2020/Jul
# uf                            ...
# Rio Grande do Sul   11422973  ...                          6.91
# São Paulo           46289333  ...                          6.11
#
# [2 rows x 4 columns]

# %%
78929703.81 / 11422973
# Out:
# 6.909733902899009

# %%
282709570.31 / 46289333
# Out:
# 6.107445322446102

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total,gastos_e_populacao,'2020/Jun')

# %%
gastos_e_populacao.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Jun
# uf                         ...
# São Paulo        46289333  ...                          6.46
# Minas Gerais     21331292  ...                          6.37
# Rio de Janeiro   17366189  ...                          4.47
# Bahia            14930634  ...                          4.36
# Paraná           11516840  ...                          8.07
#
# [5 rows x 6 columns]

# %%
gastos_e_populacao.plot(kind='bar')

# %%
gastos_e_populacao[['gasto_por_habitante_2020/Jun','gasto_por_habitante_2020/Jul']].plot(kind='bar')

# %% [markdown]
# ### Desafio: Ordenar por gasto por habitante. Ordenar por Habitantes.

# %%
# Parece aproximar bem o gasto pela população, mostrando uma função linear.
import seaborn as sns
plt.figure(figsize=(8,8))
sns.scatterplot(data = gastos_e_populacao / 1000000, x = 'populacao', y = 'gastos_2020/Jul')

# %%
# Parece aproximar bem o gasto pela população, mostrando uma função linear.
import seaborn as sns
plt.figure(figsize=(8,8))
sns.scatterplot(data = gastos_e_populacao, x = 'populacao', y = 'gasto_por_habitante_2020/Jul')

# %% [markdown]
# ### Desafio: fazer os mesmos gráficos para o mês anterior a esse.
#
# ### Desafio: fazer os últimos gráficos com os dois no mesmo gráfico.

# %% [markdown]
# ## Aula 04 - Resolvendo o Super Desafio da Aula

# %%
gastos_e_populacao.head()
# Out:
#                 populacao  ...  gasto_por_habitante_2020/Jun
# uf                         ...
# São Paulo        46289333  ...                          6.46
# Minas Gerais     21331292  ...                          6.37
# Rio de Janeiro   17366189  ...                          4.47
# Bahia            14930634  ...                          4.36
# Paraná           11516840  ...                          8.07
#
# [5 rows x 6 columns]

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao,'2020/Mai')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data = gastos_e_populacao / 1000000, x = 'populacao', y = 'gastos_2020/Mai')
sns.scatterplot(data = gastos_e_populacao / 1000000, x = 'populacao', y = 'gastos_2020/Jun')
sns.scatterplot(data = gastos_e_populacao / 1000000, x = 'populacao', y = 'gastos_2020/Jul')

# %% [markdown]
# ### Desafio: Analise os gráficos e tente chegar a hipoteses que explicam o que você está entendendo dos dados. Lembre-se que a conclusão é uma hipótese. E que esses dados serão alterados.

# %% [markdown]
# ## Aula 05 - Formatação de ticks e escalas

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2020/Jun  2020/Jul
# Unidade da Federação                      ...
# São Paulo               172.83    170.48  ...    299.06    282.71
# Minas Gerais             70.30     79.12  ...    135.98    120.47
# Paraná                   48.86     55.61  ...     92.90     80.32
# Rio Grande do Sul        45.90     52.93  ...     89.02     78.93
# Rio de Janeiro           44.12     42.89  ...     77.60     71.54
#
# [5 rows x 150 columns]

# %%
sns.scatterplot(x = ordenado_por_total.columns,y = ordenado_por_total.loc['São Paulo'])

# %%
mensal = ordenado_por_total.T
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008/Fev                 172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008/Mar                 170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008/Abr                 170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008/Mai                 172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008/Jun                 175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
# Uso tradicional do scatterplot, comparação entre colunas.
sns.scatterplot(data = mensal, x = mensal.index, y = 'São Paulo')

# %% [markdown]
# ### Desafio: Formatar o eixo y com o StrMethodFormatter, colocar um título, e colocar título nos 2 eixos. E alterar fonte (tamanho) dos títulos.

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = 'São Paulo')
plt.xticks(rotation=30)
ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=11)) #posiciona automaticamente os índices do eixo x
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ## Aula 06 - Datas com Datetime

# %%
import datetime

datetime.datetime(2020,11,3)
# Out:
# datetime.datetime(2020, 11, 3, 0, 0)

# %%
from datetime import date

meses = {
    'Jan' : 1,
    'Fev' : 2,
    'Mar' : 3,
    'Abr' : 4,
    'Mai' : 5,
    'Jun' : 6,
    'Jul' : 7,
    'Ago' : 8,
    'Set' : 9,
    'Out' : 10,
    'Nov' : 11,
    'Dez' : 12
}

def para_dia(ano_mes):
    ano: int = int(ano_mes[:4])
    mes: str = ano_mes[5:]
    mes_numero: int = meses[mes]
    
    return date(ano, mes_numero, 1)

mensal.index = mensal.index.map(para_dia)
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008-02-01               172.83         70.30   48.86  ...  1.74     0.77   1.28
# 2008-03-01               170.48         79.12   55.61  ...  2.06     0.88   1.18
# 2008-04-01               170.28         79.05   56.12  ...  2.06     0.90   1.40
# 2008-05-01               172.40         79.27   55.57  ...  2.23     1.03   1.41
# 2008-06-01               175.42         79.61   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = 'São Paulo')
plt.xticks(rotation=30)
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %%
mensal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 2008-02-01 to 2020-07-01
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   São Paulo            150 non-null    float64
#  1   Minas Gerais         150 non-null    float64
#  2   Paraná               150 non-null    float64
#  3   Rio Grande do Sul    150 non-null    float64
#  4   Rio de Janeiro       150 non-null    float64
#  5   Bahia                150 non-null    float64
#  6   Pernambuco           150 non-null    float64
#  7   Santa Catarina       150 non-null    float64
#  8   Ceará                150 non-null    float64
#  9   Goiás                150 non-null    float64
#  10  Pará                 150 non-null    float64
#  11  Maranhão             150 non-null    float64
#  12  Espírito Santo       150 non-null    float64
#  13  Rio Grande do Norte  150 non-null    float64
# ...

# %% [markdown]
# ## Aula 07 - Manipulação de dados com Melt

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal, x = mensal.index, y = 'São Paulo')
ax = sns.lineplot(data = mensal, x = mensal.index, y = 'Minas Gerais')
plt.xticks(rotation=30)
plt.ylim(0,350)
plt.grid(True, linestyle='--')

'''
Problemas:
1 - eixos
2 - legenda
3 - serio mesmo? copy e pastee das linhas do gráfico
'''
plt.show()

# %%
mensal_aberto = mensal.reset_index().melt(id_vars=['index'], value_vars = mensal.columns)
mensal_aberto.columns = ['dia_mes_ano', 'uf', 'gasto']
mensal_aberto['dia_mes_ano'] = mensal_aberto['dia_mes_ano'].astype('datetime64')
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto
# 0  2008-02-01  São Paulo 172.83
# 1  2008-03-01  São Paulo 170.48
# 2  2008-04-01  São Paulo 170.28
# 3  2008-05-01  São Paulo 172.40
# 4  2008-06-01  São Paulo 175.42

# %% [markdown]
# ### Desafio: voltar atrás... partindo do mensal_aberto chegar no mensal

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto, x = 'dia_mes_ano', y = 'gasto')
plt.xticks(rotation=30)
plt.ylim(0,100)
plt.grid(True, linestyle='--')
plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto, x = 'dia_mes_ano', y = 'gasto', hue='uf')
plt.xticks(rotation=30)
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ### Desafio: melhorar o gráfico.
#
# Problemas:
# - Muitos estado, não dá para ver nada;
# - Palette de cores: https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# ## Aula 08 - Comparando gastos ano a ano

# %%
mensal_aberto['mes'] = mensal_aberto['dia_mes_ano'].dt.month
mensal_aberto['ano'] = mensal_aberto['dia_mes_ano'].dt.year
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano
# 0  2008-02-01  São Paulo 172.83    2  2008
# 1  2008-03-01  São Paulo 170.48    3  2008
# 2  2008-04-01  São Paulo 170.28    4  2008
# 3  2008-05-01  São Paulo 172.40    5  2008
# 4  2008-06-01  São Paulo 175.42    6  2008

# %%
mensal_aberto['dia_mes_ano'].head()
# Out:
# 0   2008-02-01
# 1   2008-03-01
# 2   2008-04-01
# 3   2008-05-01
# 4   2008-06-01
# Name: dia_mes_ano, dtype: datetime64[ns]

# %%
mensal_aberto['dia_mes_ano'][0]
# Out:
# Timestamp('2008-02-01 00:00:00')

# %%
mensal_aberto.query('uf == "São Paulo"')
# Out:
#     dia_mes_ano         uf  gasto  mes   ano
# 0    2008-02-01  São Paulo 172.83    2  2008
# 1    2008-03-01  São Paulo 170.48    3  2008
# 2    2008-04-01  São Paulo 170.28    4  2008
# 3    2008-05-01  São Paulo 172.40    5  2008
# 4    2008-06-01  São Paulo 175.42    6  2008
# ..          ...        ...    ...  ...   ...
# 145  2020-03-01  São Paulo 276.61    3  2020
# 146  2020-04-01  São Paulo 251.70    4  2020
# 147  2020-05-01  São Paulo 302.86    5  2020
# 148  2020-06-01  São Paulo 299.06    6  2020
# 149  2020-07-01  São Paulo 282.71    7  2020
#
# [150 rows x 5 columns]

# %%
meses_nomes = {
    1 : 'Janeiro',
    2 : 'Fevereiro',
    3 : 'Março',
    4 : 'Abril',
    5 : 'Maio',
    6 : 'Junho',
    7 : 'Julho',
    8 : 'Agosto',
    9 : 'Setembro',
    10 : 'Outubro',
    11 : 'Novembro',
    12 : 'Desembro'
}

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf == 'São Paulo'"), x = 'mes', y = 'gasto', hue='ano')
plt.xticks(rotation=0)
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ### Deafio: cores melhores (palete), ticks de mês com o nome do mês (inglês? português?)
#
# ### Desafio: pegar dois estados de climas diferentes (estações de chuvas diferentes e plotar as diferentes linhas deles. Comparar os picos etc. Gerar gráficos separados e conjuntos. O estado que você quiser estudar.

# %%
compara_dois_estados = ['São Paulo', 'Pernambuco']

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf == 'São Paulo'"), x = 'mes', y = 'gasto', hue='ano')
ax = sns.lineplot(data = mensal_aberto.query("uf == 'Pernambuco'"), x = 'mes', y = 'gasto', hue='ano')
plt.xticks(rotation=0)
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf == 'Pernambuco'"), x = 'mes', y = 'gasto', hue='ano')
plt.xticks(rotation=0)
plt.ylim(0,350)
plt.grid(True, linestyle='--')
plt.show()

# %%
dias_por_mes = {
    1 : 31,
    2 : 28,
    3 : 31,
    4 : 30,
    5 : 31,
    6 : 30,
    7 : 31,
    8 : 31,
    9 : 30,
    10 : 31,
    11 : 30,
    12 : 31
}

# %%
mensal_aberto['gasto_diario'] = mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  diario  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008    6.17          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008    5.50          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008    5.68          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008    5.56          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008    5.85          5.85

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf == 'São Paulo'"), x = 'mes', y = 'diario', hue='ano')
plt.xticks(rotation=0)
plt.ylim(0,)
plt.grid(True, linestyle='--')
plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(data = mensal_aberto.query("uf == 'Rio de Janeiro'"), x = 'mes', y = 'gasto_diario', hue='ano', palette='Blues')
ax = sns.lineplot(data = mensal_aberto.query("uf == 'Pernambuco'"), x = 'mes', y = 'gasto_diario', hue='ano', palette='Reds')
plt.xticks(rotation=0)
plt.ylim(0,)
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ## Aula 09 - Avançando em pandas e seaborn

# %%
estado_a_analisar = mensal_aberto.query("uf == 'São Paulo'")
estado_a_analisar.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  diario  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008    6.17          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008    5.50          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008    5.68          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008    5.56          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008    5.85          5.85

# %%
gastos_por_ano = estado_a_analisar.groupby('ano').sum()
gastos_por_ano
# Out:
#        gasto  mes  diario  gasto_diario
# ano
# 2008 1960.23   77   64.60         64.60
# 2009 2489.03   78   81.82         81.82
# 2010 2696.62   78   88.63         88.63
# 2011 2794.55   78   91.91         91.91
# 2012 2873.97   78   94.47         94.47
# 2013 3062.81   78  100.67        100.67
# 2014 3200.55   78  105.25        105.25
# 2015 3187.85   78  104.79        104.79
# 2016 3200.67   78  105.26        105.26
# 2017 3302.18   78  108.53        108.53
# 2018 3379.99   78  111.11        111.11
# 2019 3488.39   78  114.69        114.69
# 2020 1986.28   28   65.60         65.60

# %%
gastos_por_ano.plot(kind = 'pie', y = 'gasto')

# %%
sns.scatterplot(data=gastos_por_ano, x = gastos_por_ano.index, y = 'gasto')

# %%
sns.lineplot(data=gastos_por_ano, x = gastos_por_ano.index, y = 'gasto')

# %%
sns.barplot(data=gastos_por_ano, x = gastos_por_ano.index, y = 'gasto', palette=sns.color_palette("rocket_r", 13))

# %% [markdown]
# ### Desafio: tom de cor ordenado PELO VALOR

# %%
estados = ["São Paulo","Minas Gerais","Pernambuco"]
por_ano_dos_estados = mensal_aberto.query("uf in @estados").groupby(["uf","ano"]).sum().reset_index()
por_ano_dos_estados
# Out:
#               uf   ano   gasto  mes  diario  gasto_diario
# 0   Minas Gerais  2008  894.35   77   29.44         29.44
# 1   Minas Gerais  2009 1149.14   78   37.77         37.77
# 2   Minas Gerais  2010 1217.49   78   40.03         40.03
# 3   Minas Gerais  2011 1315.02   78   43.24         43.24
# 4   Minas Gerais  2012 1408.35   78   46.29         46.29
# 5   Minas Gerais  2013 1514.84   78   49.79         49.79
# 6   Minas Gerais  2014 1646.22   78   54.14         54.14
# 7   Minas Gerais  2015 1660.81   78   54.61         54.61
# 8   Minas Gerais  2016 1639.97   78   53.93         53.93
# 9   Minas Gerais  2017 1727.89   78   56.79         56.79
# 10  Minas Gerais  2018 1797.03   78   59.06         59.06
# 11  Minas Gerais  2019 1879.92   78   61.80         61.80
# 12  Minas Gerais  2020  966.14   28   31.94         31.94
# 13    Pernambuco  2008  333.09   77   10.97         10.97
# 14    Pernambuco  2009  443.70   78   14.57         14.57
# ...

# %%
sns.barplot(data=por_ano_dos_estados, x = 'ano', y = 'gasto')

# %%
sns.barplot(data=por_ano_dos_estados, x = 'ano', y = 'gasto', hue='uf')

# %%
sns.catplot(data=por_ano_dos_estados, y='gasto', x='ano', kind='bar',row='uf')

# %%
sns.lineplot(data=por_ano_dos_estados, x = 'ano', y = 'gasto', hue='uf')

# %% [markdown]
# ### Desafio: Explorar a documentação (API) do seaborn. https://seaborn.pydata.org/index.html. Explorar os tutoriais. A documentação do matplotlib. https://matplotlib.org/3.1.1/gallery/index.html.
#
# ### Desafio: pensar, elaborar novos gráficos.
#
# ### Desafio: baixe uma outra base do tabnet e execute sua análise lá.

# %% [markdown]
# ## Aula 10 - Conclusão
